# %%
import pandas as pd
import folium

# %%
location="./lillios.csv"
restaurant_location=pd.read_csv(location)
resto_location=restaurant_location[["Latitude", "Longitude", "Name"]]
map = folium.Map(location=[resto_location.Latitude.mean(),resto_location.Longitude.mean()], zoom_start=10, control_scale=True)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d71e226cefccf76e6f05be42429c8921 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d71e226cefccf76e6f05be42429c8921&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d71e226cefccf76e6f05be42429c8921 = L.map(
#                 &quot;map_d71e226cefccf76e6f05be42429c8921&quot;,
#                 {
#                     center: [50.63664854999999, 5.708124066666667],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d71e226cefccf76e6f05be42429c8921);
#
#
#
#
#
#             var tile_layer_9f7ec13cb9e4f4871c8443687905f4d8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d71e226cefccf76e6f05be42429c8921);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for index, location_info in resto_location.iterrows():
    folium.Marker([location_info["Latitude"], location_info["Longitude"]], popup=location_info["Name"]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d71e226cefccf76e6f05be42429c8921 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d71e226cefccf76e6f05be42429c8921&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d71e226cefccf76e6f05be42429c8921 = L.map(
#                 &quot;map_d71e226cefccf76e6f05be42429c8921&quot;,
#                 {
#                     center: [50.63664854999999, 5.708124066666667],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d71e226cefccf76e6f05be42429c8921);
#
#
#
#
#
#             var tile_layer_9f7ec13cb9e4f4871c8443687905f4d8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d71e226cefccf76e6f05be42429c8921);
#
#
#             var marker_70ae9866a53e380905394baea0c3a974 = L.marker(
#                 [50.633, 3.0586],
#                 {}
#             ).addTo(map_d71e226cefccf76e6f05be42429c8921);
#
#
#         var popup_b88ef9144f06a02cc7be502b224d8eef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d884d72da069d2c6dff66e06bdf7096b = $(`&lt;div id=&quot;html_d884d72da069d2c6dff66e06bdf7096b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LA TABLE&lt;/div&gt;`)[0];
#                 popup_b88ef9144f06a02cc7be502b224d8eef.setContent(html_d884d72da069d2c6dff66e06bdf7096b);
#
#
#
#         marker_70ae9866a53e380905394baea0c3a974.bindPopup(popup_b88ef9144f06a02cc7be502b224d8eef)
#         ;
#
#
#
#
#             var marker_4b9c7378b42afd89b4438083897c6db2 = L.marker(
#                 [50.631752, 3.043578],
#                 {}
#             ).addTo(map_d71e226cefccf76e6f05be42429c8921);
#
#
#         var popup_2cc27650fa5ad6f77f83fe4824a2cd37 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a29f0e73b911d5a03311edeaff51c5e7 = $(`&lt;div id=&quot;html_a29f0e73b911d5a03311edeaff51c5e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PANCOOK&lt;/div&gt;`)[0];
#                 popup_2cc27650fa5ad6f77f83fe4824a2cd37.setContent(html_a29f0e73b911d5a03311edeaff51c5e7);
#
#
#
#         marker_4b9c7378b42afd89b4438083897c6db2.bindPopup(popup_2cc27650fa5ad6f77f83fe4824a2cd37)
#         ;
#
#
#
#
#             var marker_8cd827435ce07fb518739e2b37d8b315 = L.marker(
#                 [50.6307424, 3.0344337],
#                 {}
#             ).addTo(map_d71e226cefccf76e6f05be42429c8921);
#
#
#         var popup_eb17917da998639c8071d978c5e4c659 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af91653d35abc8a3c4613b72cd2c5b65 = $(`&lt;div id=&quot;html_af91653d35abc8a3c4613b72cd2c5b65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;M&#x27;EATING&lt;/div&gt;`)[0];
#                 popup_eb17917da998639c8071d978c5e4c659.setContent(html_af91653d35abc8a3c4613b72cd2c5b65);
#
#
#
#         marker_8cd827435ce07fb518739e2b37d8b315.bindPopup(popup_eb17917da998639c8071d978c5e4c659)
#         ;
#
#
#
#
#             var marker_f542443fbce6ca8de33c1e72180ce75a = L.marker(
#                 [50.6210678, 3.0555342],
#                 {}
#             ).addTo(map_d71e226cefccf76e6f05be42429c8921);
#
#
#         var popup_e3fe191ff674a26fd4329153d2e72528 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21bf89f6aedf52f62c5ae6fc00704c39 = $(`&lt;div id=&quot;html_21bf89f6aedf52f62c5ae6fc00704c39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;L&#x27;EMPIRE&lt;/div&gt;`)[0];
#                 popup_e3fe191ff674a26fd4329153d2e72528.setContent(html_21bf89f6aedf52f62c5ae6fc00704c39);
#
#
#
#         marker_f542443fbce6ca8de33c1e72180ce75a.bindPopup(popup_e3fe191ff674a26fd4329153d2e72528)
#         ;
#
#
#
#
#             var marker_8d6d8e42379b7858b58ec851f6f245a8 = L.marker(
#                 [50.6288593, 3.0589418],
#                 {}
#             ).addTo(map_d71e226cefccf76e6f05be42429c8921);
#
#
#         var popup_271304c4eb54f00de7d10f832b4804f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5702882e5885b9be07e87016616053e0 = $(`&lt;div id=&quot;html_5702882e5885b9be07e87016616053e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SEBASTOPOL&lt;/div&gt;`)[0];
#                 popup_271304c4eb54f00de7d10f832b4804f3.setContent(html_5702882e5885b9be07e87016616053e0);
#
#
#
#         marker_8d6d8e42379b7858b58ec851f6f245a8.bindPopup(popup_271304c4eb54f00de7d10f832b4804f3)
#         ;
#
#
#
#
#             var marker_63b6751a1a2e5d08fae05acbbf8d

# %%
map.save("map.html")
